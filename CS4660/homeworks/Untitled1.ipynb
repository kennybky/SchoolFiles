# %%
import numpy as np
import pandas as pd
data = pd.read_csv('http://mlr.cs.umass.edu/ml/machine-learning-databases/adult/adult.data',
                   names = ["","","","","","","","","","Gender","","","","",""])

# %%
data[0::10]
# Out:
#                           .1      .2             .3  .4  \
# 0      39          State-gov   77516      Bachelors  13
# 10     37            Private  280464   Some-college  10
# 20     40            Private  193524      Doctorate  16
# 30     23          Local-gov  190709     Assoc-acdm  12
# 40     31            Private  507875            9th   5
# 50     25            Private   32275   Some-college  10
# 60     30            Private   59496      Bachelors  13
# 70     19            Private  101509   Some-college  10
# 80     18            Private  446839        HS-grad   9
# 90     57            Private  249977      Assoc-voc  11
# 100    76            Private  124191        Masters  14
# 110    24            Private  432376      Bachelors  13
# 120    21            Private  199915   Some-college  10
# 130    28            Private   69621     Assoc-acdm  12
# 140    61       Self-emp-inc   66614        HS-grad   9
# 150    47          Local-gov  186009   Some-college  10
# ...

# %%
data.fillna(data.mean)
# Out:
#                           .1      .2             .3  .4  \
# 0      39          State-gov   77516      Bachelors  13
# 1      50   Self-emp-not-inc   83311      Bachelors  13
# 2      38            Private  215646        HS-grad   9
# 3      53            Private  234721           11th   7
# 4      28            Private  338409      Bachelors  13
# 5      37            Private  284582        Masters  14
# 6      49            Private  160187            9th   5
# 7      52   Self-emp-not-inc  209642        HS-grad   9
# 8      31            Private   45781        Masters  14
# 9      42            Private  159449      Bachelors  13
# 10     37            Private  280464   Some-college  10
# 11     30          State-gov  141297      Bachelors  13
# 12     23            Private  122272      Bachelors  13
# 13     32            Private  205019     Assoc-acdm  12
# 14     40            Private  121772      Assoc-voc  11
# 15     34            Private  245487        7th-8th   4
# ...

# %%
data.mode()
# Out:
#                .1      .2        .3   .4                   .5  \
# 0  36.0   Private  123011   HS-grad  9.0   Married-civ-spouse
# 1   NaN       NaN  164190       NaN  NaN                  NaN
# 2   NaN       NaN  203488       NaN  NaN                  NaN
#
#                 .6        .7      .8 Gender   .9  .10   .11             .12  \
# 0   Prof-specialty   Husband   White   Male  0.0  0.0  40.0   United-States
# 1              NaN       NaN     NaN    NaN  NaN  NaN   NaN             NaN
# 2              NaN       NaN     NaN    NaN  NaN  NaN   NaN             NaN
#
#       .13
# 0   <=50K
# 1     NaN
# 2     NaN

# %%
data['Gender'].mode()
# Out:
# 0     Male
# dtype: object

# %%
data.replace(' ?',data.mode)
# Out:
#                                                           .1      .2  \
# 0      39                                          State-gov   77516
# 1      50                                   Self-emp-not-inc   83311
# 2      38                                            Private  215646
# 3      53                                            Private  234721
# 4      28                                            Private  338409
# 5      37                                            Private  284582
# 6      49                                            Private  160187
# 7      52                                   Self-emp-not-inc  209642
# 8      31                                            Private   45781
# 9      42                                            Private  159449
# 10     37                                            Private  280464
# 11     30                                          State-gov  141297
# 12     23                                            Private  122272
# ...

# %%
a = np.array(data)
print(a[:,-1])
# Out:
# [' <=50K' ' <=50K' ' <=50K' ..., ' <=50K' ' <=50K' ' >50K']

# %% [markdown]
# print(a[:,0:-1])

# %% [markdown]
# # Hey
