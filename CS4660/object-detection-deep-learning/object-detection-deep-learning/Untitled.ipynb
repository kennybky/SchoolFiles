# %%
import objectDetection as ob
ob.detect("MobileNetSSD_deploy.prototxt.txt","MobileNetSSD_deploy.caffemodel","images/example_06.jpg")
# Out:
# [INFO] loading model...
# [INFO] computing object detections...
# [INFO] dog: 93.76%
# [INFO] person: 99.98%

# %%
ob.detect("MobileNetSSD_deploy.prototxt.txt","MobileNetSSD_deploy.caffemodel","images/example_03.jpg")
# Out:
# [INFO] loading model...
# [INFO] computing object detections...
# [INFO] horse: 99.84%
# [INFO] pottedplant: 99.06%

# %%
ob.detect("MobileNetSSD_deploy.prototxt.txt","MobileNetSSD_deploy.caffemodel","images/example_01.jpg")
# Out:
# [INFO] loading model...
# [INFO] computing object detections...
# [INFO] car: 99.96%
# [INFO] car: 95.68%
